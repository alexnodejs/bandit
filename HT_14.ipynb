# %% [markdown]
# <a href="https://colab.research.google.com/github/alexnodejs/bandit/blob/main/HT_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Імпорт модулів

# %%
import pandas as pd
from torch.utils.data import Dataset
import torch
from sklearn.model_selection import train_test_split

# %% [markdown]
# Дані про гриби
#
# [посилання](https://www.kaggle.com/datasets/uciml/mushroom-classification)

# %%
# трохи обробки даних
from sklearn.preprocessing import OrdinalEncoder

df = pd.read_csv('https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/mushrooms.csv')
df = df.drop(columns='veil-type')

encoder = OrdinalEncoder().set_output(transform='pandas')
df = encoder.fit_transform(df).astype(int)

columns = df.columns.delete(0)
data = df[columns]
df[columns] = (data - data.min()) / (data.max() - data.min())

# %% [markdown]
# Дані непогано збалансовані

# %%
df['class'].value_counts()
# Out:
# class
# 0    4208
# 1    3916
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises   odor  gill-attachment  \
# 0      1        1.0     0.666667   0.444444      1.0  0.750              1.0
# 1      0        1.0     0.666667   1.000000      1.0  0.000              1.0
# 2      0        0.0     0.666667   0.888889      1.0  0.375              1.0
# 3      1        1.0     1.000000   0.888889      1.0  0.750              1.0
# 4      0        1.0     0.666667   0.333333      0.0  0.625              1.0
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-above-ring  \
# 0           0.0        1.0    0.363636  ...                  0.666667
# 1           0.0        0.0    0.363636  ...                  0.666667
# 2           0.0        0.0    0.454545  ...                  0.666667
# 3           0.0        1.0    0.454545  ...                  0.666667
# 4           1.0        0.0    0.363636  ...                  0.666667
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                  0.666667                   0.875                   0.875
# 1                  0.666667                   0.875                   0.875
# 2                  0.666667                   0.875                   0.875
# 3                  0.666667                   0.875                   0.875
# 4                  0.666667                   0.875                   0.875
#
#    veil-color  ring-number  ring-type  spore-print-color  population   habitat
# 0    0.666667          0.5        1.0              0.250         0.6  0.833333
# 1    0.666667          0.5        1.0              0.375         0.4  0.166667
# 2    0.666667          0.5        1.0              0.375         0.4  0.500000
# 3    0.666667          0.5        1.0              0.250         0.6  0.833333
# 4    0.666667          0.5        0.0              0.375         0.0  0.166667
#
# [5 rows x 22 columns]

# %% [markdown]
# Потрібно на основі інформації про гриб зрозуміти чи він їстівним(клас 1) `class`

# %% [markdown]
# # Завдання 1
# Створіть клас Dataset для тренувальних та тестових даних

# %%
class MyDataset(Dataset):
    def __init__(self, X, y):
      self.X = torch.tensor(X.values, dtype=torch.float32)
      self.y = torch.LongTensor(y.values)

    def __len__(self):
      return len(self.X)

    def __getitem__(self, idx):
      return self.X[idx], self.y[idx]

X = df.drop(columns=['class'])
y = df['class']

dataset = MyDataset(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size=0.8,
                                                    random_state=42,
                                                    stratify=y)

dataset_train = MyDataset(X_train, y_train)
dataset_test = MyDataset(X_test, y_test)

# %% [markdown]
# # Завдання 2
# Створіть DataLoader

# %%
from torch.utils.data import DataLoader

batch_size = 512

test_dl = DataLoader(dataset_test,
                     batch_size=batch_size,
                     shuffle=True)

train_dl = DataLoader(dataset_train,
                      batch_size=batch_size,
                      shuffle=True)

# %% [markdown]
# # Завдання 3
# Створіть нейромережу

# %%
import torch.nn as nn
import torch.optim as optim

class MultiClassClassifier(nn.Module):
    def __init__(self, input_dim):
        super(MultiClassClassifier, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 16)
        self.fc4 = nn.Linear(16, 2)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# Initialize the model
input_size = X.shape[1]
model = MultiClassClassifier(input_size)

# %%
from torchsummary import summary

summary(model, input_size=(21,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                   [-1, 64]           1,408
#             Linear-2                   [-1, 32]           2,080
#             Linear-3                   [-1, 16]             528
#             Linear-4                    [-1, 2]              34
# ================================================================
# Total params: 4,050
# Trainable params: 4,050
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.02
# ----------------------------------------------------------------

# %% [markdown]
# # Завдання 4
# Визначте функцію втрат та оптимізатор, можливо графік швидкості навчання

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-2)

# %% [markdown]
# # Завдання 5
# Натренуйте нейромережу.

# %%
# @title Функція для тренування
import time

def train(model, optimizer, loss_fn, train_dl, val_dl,
          metrics=None, metrics_name=None, epochs=20, device='cpu', task='regression'):
    '''
    Runs training loop for classification problems. Returns Keras-style
    per-epoch history of loss and accuracy over training and validation data.

    Parameters
    ----------
    model : nn.Module
        Neural network model
    optimizer : torch.optim.Optimizer
        Search space optimizer (e.g. Adam)
    loss_fn :
        Loss function (e.g. nn.CrossEntropyLoss())
    train_dl :
        Iterable dataloader for training data.
    val_dl :
        Iterable dataloader for validation data.
    metrics: list
        List of sklearn metrics functions to be calculated
    metrics_name: list
        List of matrics names
    epochs : int
        Number of epochs to run
    device : string
        Specifies 'cuda' or 'cpu'
    task : string
        type of problem. It can be regression, binary or multiclass

    Returns
    -------
    Dictionary
        Similar to Keras' fit(), the output dictionary contains per-epoch
        history of training loss, training accuracy, validation loss, and
        validation accuracy.
    '''

    print('train() called: model=%s, opt=%s(lr=%f), epochs=%d, device=%s\n' % \
          (type(model).__name__, type(optimizer).__name__,
           optimizer.param_groups[0]['lr'], epochs, device))

    metrics = metrics if metrics else []
    metrics_name = metrics_name if metrics_name else [metric.__name__ for metric in metrics]

    history = {} # Collects per-epoch loss and metrics like Keras' fit().
    history['loss'] = []
    history['val_loss'] = []
    for name in metrics_name:
        history[name] = []
        history[f'val_{name}'] = []

    start_time_train = time.time()

    for epoch in range(epochs):

        # --- TRAIN AND EVALUATE ON TRAINING SET -----------------------------
        start_time_epoch = time.time()

        model.train()
        history_train = {name: 0 for name in ['loss']+metrics_name}

        for batch in train_dl:
            x    = batch[0].to(device)
            y    = batch[1].to(device)
            y_pred = model(x)
            loss = loss_fn(y_pred, y)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            y_pred = y_pred.detach().cpu().numpy()
            y = y.detach().cpu().numpy()


            history_train['loss'] += loss.item() * x.size(0)
            for name, func in zip(metrics_name, metrics):
              try:
                  history_train[name] += func(y, y_pred) * x.size(0)
              except:
                  if task == 'binary': y_pred_ = y_pred.round()
                  elif task == 'multiclass': y_pred_ = y_pred.argmax(axis=-1)
                  history_train[name] += func(y, y_pred_) * x.size(0)

        for name in history_train:
            history_train[name] /= len(train_dl.dataset)


        # --- EVALUATE ON VALIDATION SET -------------------------------------
        model.eval()
        history_val = {'val_' + name: 0 for name in metrics_name+['loss']}

        with torch.no_grad():
            for batch in val_dl:
                x    = batch[0].to(device)
                y    = batch[1].to(device)
                y_pred = model(x)
                loss = loss_fn(y_pred, y)

                y_pred = y_pred.cpu().numpy()
                y = y.cpu().numpy()

                history_val['val_loss'] += loss.item() * x.size(0)
                for name, func in zip(metrics_name, metrics):
                    try:
                        history_val['val_'+name] += func(y, y_pred) * x.size(0)
                    except:
                        if task == 'binary': y_pred_ = y_pred.round()
                        elif task == 'multiclass': y_pred_ = y_pred.argmax(axis=-1)

                        history_val['val_'+name] += func(y, y_pred_) * x.size(0)

        for name in history_val:
            history_val[name] /= len(val_dl.dataset)

        # PRINTING RESULTS

        end_time_epoch = time.time()

        for name in history_train:
            history[name].append(history_train[name])
            history['val_'+name].append(history_val['val_'+name])

        total_time_epoch = end_time_epoch - start_time_epoch

        print(f'Epoch {epoch+1:4d} {total_time_epoch:4.0f}sec', end='\t')
        for name in history_train:
            print(f'{name}: {history[name][-1]:10.3g}', end='\t')
            print(f"val_{name}: {history['val_'+name][-1]:10.3g}", end='\t')
        print()

    # END OF TRAINING LOOP

    end_time_train       = time.time()
    total_time_train     = end_time_train - start_time_train
    print()
    print('Time total:     %5.2f sec' % (total_time_train))

    return history

# %%
from sklearn.metrics import accuracy_score

metrics = [accuracy_score]
metrics_name = ['accuracy']

device = "cuda" if torch.cuda.is_available() else "cpu"
torch.set_default_device(device)

history = train(model=model,
                optimizer=optimizer,
                loss_fn=loss_fn,
                train_dl=train_dl,
                val_dl=test_dl,
                epochs=70,
                metrics=metrics,
                metrics_name=metrics_name, # In many classes classificaton we can disable roc_auc_score
                device=device,
                task='multiclass')
# Out:
# train() called: model=MultiClassClassifier, opt=Adam(lr=0.010000), epochs=70, device=cpu
#
# Epoch    1    1sec	loss:     0.0063	val_loss:    0.00553	accuracy:      0.998	val_accuracy:      0.998
# Epoch    2    0sec	loss:    0.00187	val_loss:    0.00125	accuracy:          1	val_accuracy:          1
# Epoch    3    0sec	loss:    0.00102	val_loss:   0.000276	accuracy:          1	val_accuracy:          1
# Epoch    4    0sec	loss:     0.0003	val_loss:   0.000132	accuracy:          1	val_accuracy:          1
# Epoch    5    0sec	loss:   0.000142	val_loss:   0.000124	accuracy:          1	val_accuracy:          1
# Epoch    6    0sec	loss:   8.02e-05	val_loss:   7.04e-05	accuracy:          1	val_accuracy:          1
# Epoch    7    0sec	loss:   5.68e-05	val_loss:   6.07e-05	accuracy:          1	val_accuracy:          1
# Epoch    8    0sec	loss:   4.89e-05	val_loss:   5.88e-05	accuracy:          1	val_accuracy:          1
# Epoch    9    0sec	loss:   4.35e-05	val_loss:   5.32e-05	accuracy:          1	val_accuracy:          1
# Epoch   10    0sec	loss:   4.07e-05	val_loss:   4.98e-05	accuracy:          1	val_accuracy:          1
# Epoch   11    0sec	loss:   3.84e-05	val_loss:   4.78e-05	accuracy:          1	val_accuracy:          1
# Epoch   12    0sec	loss:   3.61e-05	val_loss:   4.72e-05	accuracy:          1	val_accuracy:          1
# Epoch   13    0sec	loss:   3.47e-05	val_loss:   4.48e-05	accuracy:          1	val_accuracy:          1
# Epoch   14    0sec	loss:   3.33e-05	val_loss:    4.5e-05	accuracy:          1	val_accuracy:          1
# Epoch   15    0sec	loss:   3.22e-05	val_loss:   4.15e-05	accuracy:          1	val_accuracy:          1
# Epoch   16    0sec	loss:   3.05e-05	val_loss:    4.2e-05	accuracy:          1	val_accuracy:          1
# Epoch   17    0sec	loss:   2.97e-05	val_loss:   3.88e-05	accuracy:          1	val_accuracy:          1
# Epoch   18    0sec	loss:    2.9e-05	val_loss:   4.01e-05	accuracy:          1	val_accuracy:          1
# Epoch   19    0sec	loss:   2.77e-05	val_loss:   3.63e-05	accuracy:          1	val_accuracy:          1
# Epoch   20    0sec	loss:   2.65e-05	val_loss:   3.69e-05	accuracy:          1	val_accuracy:          1
# Epoch   21    0sec	loss:   2.59e-05	val_loss:   3.67e-05	accuracy:          1	val_accuracy:          1
# Epoch   22    0sec	loss:   2.47e-05	val_loss:   3.37e-05	accuracy:          1	val_accuracy:          1
# Epoch   23    0sec	loss:   2.44e-05	val_loss:   3.32e-05	accuracy:          1	val_accuracy:          1
# Epoch   24    0sec	loss:   2.38e-05	val_loss:    3.3e-05	accuracy:          1	val_accuracy:          1
# Epoch   25    0sec	loss:   2.27e-05	val_loss:   3.11e-05	accuracy:          1	val_accuracy:          1
# Epoch   26    0sec	loss:   2.24e-05	val_loss:   3.13e-05	accuracy:          1	val_accuracy:          1
# Epoch   27    0sec	loss:   2.18e-05	val_loss:   3.02e-05	accuracy:          1	val_accuracy:          1
# Epoch   28    0sec	loss:    2.1e-05	val_loss:   2.87e-05	accuracy:          1	val_accuracy:          1
# Epoch   29    0sec	loss:   2.04e-05	val_loss:    2.9e-05	accuracy:          1	val_accuracy:          1
# Epoch   30    0sec	loss:   2.01e-05	val_loss:    2.9e-05	accuracy:          1	val_accuracy:          1
# Epoch   31    0sec	loss:   2.04e-05	val_loss:   2.69e-05	accuracy:          1	val_accuracy:          1
# Epoch   32    0sec	loss:   1.91e-05	val_loss:   2.77e-05	accuracy:          1	val_accuracy:          1
# Epoch   33    0sec	loss:   1.88e-05	val_loss:   2.61e-05	accuracy:          1	val_accuracy:          1
# Epoch   34    0sec	loss:    1.8e-05	val_loss:   2.59e-05	accuracy:          1	val_accuracy:          1
# Epoch   35    0sec	loss:   1.78e-05	val_loss:   2.52e-05	accuracy:          1	val_accuracy:          1
# Epoch   36    0sec	loss:   1.74e-05	val_loss:   2.43e-05	accuracy:          1	val_accuracy:          1
# Epoch   37    0sec	loss:   1.69e-05	val_loss:   2.44e-05	accuracy:          1	val_accuracy:          1
# Epoch   38    0sec	loss:   1.66e-05	val_loss:    2.3e-05	accuracy:          1	val_accuracy:          1
# Epoch   39    0sec	loss:   1.61e-05	val_loss:   2.38e-05	accuracy:          1	val_accuracy:          1
# Epoch   40    0sec	loss:    1.6e-05	val_loss:   2.26e-05	accuracy:          1	val_accuracy:          1
# Epoch   41    0sec	loss:   1.55e-05	val_loss:   2.14e-05	accuracy:          1	val_accuracy:          1
# Epoch   42    0sec	loss:    1.5e-05	val_loss:   2.19e-05	accuracy:          1	val_accuracy:          1
# Epoch   43    0sec	loss:    1.5e-05	val_loss:   2.15e-05	accuracy:          1	val_accuracy:          1
# Epoch   44    0sec	loss:   1.46e-05	val_loss:      2e-05	accuracy:          1	val_accuracy:          1
# Epoch   45    0sec	loss:   1.42e-05	val_loss:   2.13e-05	accuracy:          1	val_accuracy:          1
# Epoch   46    0sec	loss:   1.41e-05	val_loss:   2.03e-05	accuracy:          1	val_accuracy:          1
# Epoch   47    0sec	loss:   1.34e-05	val_loss:   1.87e-05	accuracy:          1	val_accuracy:          1
# Epoch   48    0sec	loss:   1.35e-05	val_loss:   1.91e-05	accuracy:          1	val_accuracy:          1
# Epoch   49    0sec	loss:   1.33e-05	val_loss:   1.97e-05	accuracy:          1	val_accuracy:          1
# Epoch   50    0sec	loss:    1.3e-05	val_loss:   1.77e-05	accuracy:          1	val_accuracy:          1
# Epoch   51    0sec	loss:   1.26e-05	val_loss:   1.84e-05	accuracy:          1	val_accuracy:          1
# Epoch   52    0sec	loss:   1.23e-05	val_loss:   1.75e-05	accuracy:          1	val_accuracy:          1
# Epoch   53    0sec	loss:   1.21e-05	val_loss:    1.7e-05	accuracy:          1	val_accuracy:          1
# Epoch   54    0sec	loss:   1.17e-05	val_loss:   1.73e-05	accuracy:          1	val_accuracy:          1
# Epoch   55    0sec	loss:   1.19e-05	val_loss:   1.65e-05	accuracy:          1	val_accuracy:          1
# Epoch   56    0sec	loss:   1.13e-05	val_loss:   1.58e-05	accuracy:          1	val_accuracy:          1
# Epoch   57    0sec	loss:   1.12e-05	val_loss:   1.59e-05	accuracy:          1	val_accuracy:          1
# Epoch   58    0sec	loss:   1.09e-05	val_loss:   1.61e-05	accuracy:          1	val_accuracy:          1
# Epoch   59    0sec	loss:   1.08e-05	val_loss:   1.52e-05	accuracy:          1	val_accuracy:          1
# Epoch   60    0sec	loss:   1.07e-05	val_loss:   1.47e-05	accuracy:          1	val_accuracy:          1
# Epoch   61    0sec	loss:   1.06e-05	val_loss:   1.59e-05	accuracy:          1	val_accuracy:          1
# Epoch   62    0sec	loss:   1.03e-05	val_loss:   1.42e-05	accuracy:          1	val_accuracy:          1
# Epoch   63    0sec	loss:   9.92e-06	val_loss:   1.44e-05	accuracy:          1	val_accuracy:          1
# Epoch   64    0sec	loss:   9.76e-06	val_loss:   1.41e-05	accuracy:          1	val_accuracy:          1
# Epoch   65    0sec	loss:   9.63e-06	val_loss:   1.42e-05	accuracy:          1	val_accuracy:          1
# Epoch   66    0sec	loss:   9.61e-06	val_loss:   1.35e-05	accuracy:          1	val_accuracy:          1
# Epoch   67    0sec	loss:   9.39e-06	val_loss:    1.3e-05	accuracy:          1	val_accuracy:          1
# Epoch   68    0sec	loss:   9.04e-06	val_loss:   1.32e-05	accuracy:          1	val_accuracy:          1
# Epoch   69    0sec	loss:   9.03e-06	val_loss:   1.35e-05	accuracy:          1	val_accuracy:          1
# Epoch   70    0sec	loss:   8.79e-06	val_loss:   1.22e-05	accuracy:          1	val_accuracy:          1
#
# Time total:     14.35 sec

# %% [markdown]
# # Завдання 6
# Виведіть графік метрик та матрицю помилок

# %%
import matplotlib.pyplot as plt

def plot_metric(history, name):
  plt.title(f"Model results with {name}")
  plt.plot(history[name], label='train')
  plt.plot(history['val_'+name], label='val')
  plt.xlabel('Epoch')
  plt.ylabel(name)
  plt.legend()


plot_metric(history, 'loss')
